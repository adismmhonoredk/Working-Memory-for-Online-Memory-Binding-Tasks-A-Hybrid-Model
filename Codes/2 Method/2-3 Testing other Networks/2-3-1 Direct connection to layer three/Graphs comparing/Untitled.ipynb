# %% [markdown]
# # We save both models' Loss function per each epochs and compare them here.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import dill

# %%
history=[]
history1=[]

# %%
history= dill.load(open("history.pickle", "rb"))
history1= dill.load(open("history2.pickle", "rb"))

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(6,5), dpi=300)
plt.plot(history, label='IV to Third Layer')
plt.plot(history1, label='Our Model')
plt.title(label='Loss')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.legend()
plt.show()
fig.savefig('HistoryVS.png')
# Out:
# <img src="data:image/png;base64,..." width="1800">
